# %% [markdown]
# # Potential Energy Scans and Visualisation of Trajectories
#
# The range of problems that can be tackled with Psi4 or other electronic structure packages is not limited
# to wavefunction or geometry optimisations. We can use python to create complex inputs, adjusting various settings, or making specific modifications of
# some variables.
#
# In this set of exercises, you will instruct Psi4 to
# selectively scan one degree of freedom of a potential energy surface.
#
# <button name="button" class="btn px-3 py-1 enc-btn">[📥 Download introductory slides](https://github.com/lcbc-epfl/iesm-public/blob/gh-pages/Exercises/Ex8/Slides_Ex8.md.pdf)</button>
#
#
# [ <img src="https://badgen.net/static/Report%20Template/Google%20Docs/yellow" />](https://drive.google.com/viewer?url=https://lcbc-epfl.github.io/iesm-public/templates/exercise-template-ex8.docx)
#
# [<img src="https://badgen.net/static/Report%20Template/Overleaf/green"/>](https://www.overleaf.com/docs?snip_uri=https://lcbc-epfl.github.io/iesm-public/templates/exercise-template-ex8.tex)
#
# ::::{grid}
# :gutter: 3
#
# :::{grid-item-card}
#
# 🎯 **Learning goals**
# ^^^
# Differentiate between rigid and relaxed PES scans
# Connect results of PES scans to known molecular properties
#
# :::
#
# :::{grid-item-card}
#
# 📖 **Chapter in script**
# ^^^
#
# :::
#
# :::{grid-item-card}
#
# 📚 **Resources**
# ^^^
#
# :::
# ::::
