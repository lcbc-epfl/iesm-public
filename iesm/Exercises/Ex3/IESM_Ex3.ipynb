# %% [markdown]
# # Large Basis Sets, Dissociation Energy and Geometry Optimisation
#
# Albeit deceptively small and simple, the H$_2$ molecule with its two
# protons and two electrons is already too big to derive an analytic
# solution of the Schrödinger equation. However, one may construct a
# special basis set that is arbitrarily close to the complete basis set
# limit, and then run a post-Hartree Fock calculation. Using such
# techniques, it was found that, for the H$_2$ molecule,
# $E_{exact} = -1.174474{}$ a.u.
#
# In this set of exercises, you will compare the influence of basis sets
# on the energy of H$_2$ at equilibrium distance, and you will then go on
# to compute the dissociation energy of H$_2$ using Hartree Fock.
#
# Subsequently, you will determine the equilibrium geometry of a species
# using the example of water.
#
# <button name="button" class="btn px-3 py-1 enc-btn">[📥 Download introductory slides](https://github.com/lcbc-epfl/iesm-public/blob/gh-pages/Exercises/Ex3/Slides_Ex3.md.pdf)</button>
#
# [ <img src="https://badgen.net/static/Report%20Template/Google%20Docs/yellow" />](https://drive.google.com/viewer?url=https://lcbc-epfl.github.io/iesm-public/templates/exercise-template-ex3.docx)
#
# [<img src="https://badgen.net/static/Report%20Template/Overleaf/green"/>](https://www.overleaf.com/docs?snip_uri=https://lcbc-epfl.github.io/iesm-public/templates/exercise-template-ex3.tex)
#
# ::::{grid}
# :gutter: 3
#
# :::{grid-item-card}
#
# 🎯 **Learning goals**
# ^^^
#
# Influence of basis sets
#
# Geometry optimization procedure
#
# Basics of HF theory: RHF vs UHF
# :::
#
# :::{grid-item-card}
#
# 📖 **Chapter in script**
# ^^^
#
# Chapter 3 - Basis functions in quantum chemistry
#
# Chapter 4 - An introduction to Hartree Fock theory
# :::
#
# :::{grid-item-card}
#
# 📚 **Resources**
# ^^^
#
# Jensen, F. (2017). Introduction to computational chemistry. John wiley & sons.
# * Chapter 5 - Basis Sets
#
# Introduction to Hartree-Fock Molecular Orbital Theory  by the Sherrill group: [slides](http://vergil.chemistry.gatech.edu/courses/chem6485/pdf/Hartree-Fock-Intro.pdf) and videos ([part 1](http://www.youtube.com/watch?v=6XFOF8-QkAM&feature=relmfu), [part 2](http://www.youtube.com/watch?v=1jHkt1Qzv1A&feature=relmfu))
#
# Geometry Optimization by the Sherrill group: [slides](http://vergil.chemistry.gatech.edu/courses/chem6485/pdf/geom-opt.pdf) and [video](http://www.youtube.com/watch?v=QuoRCyYrS9s)
# :::
# ::::
