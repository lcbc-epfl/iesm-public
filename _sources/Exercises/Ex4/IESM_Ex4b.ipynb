# %% [markdown]
# # The hartree fock procedure in detail
#
# So far you have run some Hartree Fock calculations using Psi4 and in the lectures we have seen the theoretical derivation of the scheme.
#
# In this exercise, we will recapitulate the HF scheme by implementing it on our own using Psi4. That means we will go through the steps of the HF procedure but we will let Psi4 evaluate the integrals for us.
#
# <button name="button" class="btn px-3 py-1 enc-btn">[📥 Download introductory slides](https://github.com/lcbc-epfl/iesm-public/raw/main/iesm/Exercises/Ex4/Slides_Ex4b.pdf)</button>
#
# ::::{grid}
# :gutter: 3
#
# :::{grid-item-card}
#
# 🎯 **Learning goals**
# ^^^
#
# Build and diagonalize the Fock matrix
#
# Understand the steps in a HF SCF calculation
#
# Practice implicit summation in numpy
# :::
#
# :::{grid-item-card}
#
# 📖 **Chapter in script**
# ^^^
# Chapter 4 - An introduction to Hartree Fock theory
# Appendix C
# :::
#
# :::{grid-item-card}
#
# 📚 **Resources**
# ^^^
# Introduction to Hartree-Fock Molecular Orbital Theory  by the Sherrill group: [slides](http://vergil.chemistry.gatech.edu/courses/chem6485/pdf/Hartree-Fock-Intro.pdf) and videos ([part 1](http://www.youtube.com/watch?v=6XFOF8-QkAM&feature=relmfu), [part 2](http://www.youtube.com/watch?v=1jHkt1Qzv1A&feature=relmfu))
# :::
# ::::
